# %%
# %load_ext autoreload
# %autoreload 2


from sbifitter import Simformer_Fitter

# %%
grid_path = "/cosma7/data/dp276/dc-harv3/work/sbifitter/grids/grid_BPASS_Chab_LogNormal_SFH_0.0_z_12_logN_5.0_Calzetti_v1.hdf5"  # noqa: E501

fitter = Simformer_Fitter.load_saved_model('/cosma/apps/dp276/dc-harv3/sbifitter/models/simformer_v2')

# %%
fitter.create_feature_array_from_raw_photometry();

# %%
fitter.plot_histogram_feature_array(bins="scott");

# %%
fitter.plot_histogram_feature_array();

# %%
fitter.run_single_sbi()
