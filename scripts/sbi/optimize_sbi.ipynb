# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
from ltu_ili_testing import SBI_Fitter

grid_path = '/home/tharvey/work/output/grid_Pop_II_LogNormal_SFH_5_z_12_logN_5.0_BPASS_Chab_v1.hdf5'
# Out:
# Device: cuda
# Pytorch version: 2.4.1
# ROCM HIP version: 6.1.40093-e3dc58bf0

# %%
fitter = SBI_Fitter.init_from_hdf5('BPASS_Chab_LogNorm_5_z_12_optimize', 
                                grid_path, return_output=False, device='cpu')


fitter.create_feature_array_from_raw_photometry(extra_features=[],
                                                normalize_method=None);
# Out:
# ---------------------------------------------
# Features: 100000 features over 20 samples
# ---------------------------------------------
# Feature: Min - Max
# ---------------------------------------------
# NIRCam.F070W: 21.384 - 50.000 AB
# NIRCam.F090W: 19.759 - 50.000 AB
# NIRCam.F115W: 19.533 - 50.000 AB
# NIRCam.F140M: 19.640 - 50.000 AB
# NIRCam.F150W: 19.666 - 42.887 AB
# NIRCam.F162M: 19.382 - 41.489 AB
# NIRCam.F182M: 19.386 - 41.191 AB
# NIRCam.F200W: 19.375 - 41.193 AB
# NIRCam.F210M: 19.360 - 41.262 AB
# NIRCam.F250M: 19.415 - 40.193 AB
# NIRCam.F277W: 19.419 - 39.720 AB
# NIRCam.F300M: 19.431 - 39.453 AB
# NIRCam.F335M: 18.688 - 39.107 AB
# NIRCam.F356W: 19.162 - 38.960 AB
# NIRCam.F360M: 18.896 - 38.955 AB
# NIRCam.F410M: 19.350 - 38.677 AB
# NIRCam.F430M: 18.503 - 38.605 AB
# NIRCam.F444W: 19.162 - 38.420 AB
# NIRCam.F460M: 18.377 - 38.405 AB
# NIRCam.F480M: 19.062 - 38.008 AB
# ---------------------------------------------

# %%
fitter.optimize_sbi(study_name='BPASS_Chab_LogNorm_5_z_12_optimize2',
                    suggested_hyperparameters=
                        {
                            "learning_rate": [1e-5, 1e-2],
                            "hidden_features": [12, 200],
                            "num_components": [2, 16],
                            "training_batch_size": [32, 128],
                            "num_transforms": [1, 4],
                            "stop_after_epochs": [10, 30],
                        },
                    n_trials=40,
                    n_jobs=7,
                    verbose=True,
)
# Out:
# [I 2025-05-16 18:00:08,857] A new study created in memory with name: BPASS_Chab_LogNorm_5_z_12_optimize2
# Splitting dataset with 100000 samples into training and testing sets with 0.80 train fraction.
#   0%|          | 0/40 [00:00<?, ?it/s]
# INFO:root:MODEL INFERENCE CLASS: NPE
# INFO:root:MODEL INFERENCE CLASS: NPE
# INFO:root:MODEL INFERENCE CLASS: NPE
# INFO:root:MODEL INFERENCE CLASS: NPE
# INFO:root:MODEL INFERENCE CLASS: NPE
# INFO:root:MODEL INFERENCE CLASS: NPE
# INFO:root:MODEL INFERENCE CLASS: NPE
# ---------------------------------------------
# Prior ranges:
# ---------------------------------------------
# redshift: 5.00 - 12.00
# log_mass: 6.00 - 11.50
# sps_Pop_II_LogNormal_SFH_5_z_12_logN_5.0_BPASS_Chab_v1/tau_v: 0.00 - 2.00
# sps_Pop_II_LogNormal_SFH_5_z_12_logN_5.0_BPASS_Chab_v1/tau: 0.05 - 2.50
# sps_Pop_II_LogNormal_SFH_5_z_12_logN_5.0_BPASS_Chab_v1/peak_age: 0.00 - 990.40
# sps_Pop_II_LogNormal_SFH_5_z_12_logN_5.0_BPASS_Chab_v1/log10metallicity: -3.00 - -1.39
# ...

# %%
fitter.sample_posterior()
# Out:
# None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 fitter.sample_posterior()
#
# File <string>:10, in sample_posterior(self, X_test, sample_method, sample_kwargs, posteriors, num_samples)
#
# ValueError: X_test must be provided or set in the object.

# %%
fitter.load_model_from_pkl('/home/tharvey/work/ltu-ili_testing/models/BPASS_Chab_LogNorm_5_z_12_phot_grid2_redshift')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 fitter.load_model_from_pkl('/home/tharvey/work/ltu-ili_testing/models/BPASS_Chab_LogNorm_5_z_12_phot_grid2_redshift')
#
# File <string>:16, in load_model_from_pkl(self, model_file, set_self)
#
# File ~/work/ltu-ili_testing/.venv/lib/python3.11/site-packages/joblib/numpy_pickle.py:733, in load(filename, mmap_mode, ensure_native_byte_order)
#     731     filename = getattr(fobj, "name", "")
#     732     with _validate_fileobject_and_memmap(fobj, filename, mmap_mode) as (fobj, _):
# --> 733         obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734 else:
#     735     with open(filename, "rb") as f:
#
# File ~/work/ltu-ili_testing/.venv/lib/python3.11/site-packages/joblib/numpy_pickle.py:626, in _unpickle(fobj, ensure_native_byte_order, filename, mmap_mode)
# ...
