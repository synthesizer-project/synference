# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
from ltu_ili_testing import SBI_Fitter

grid_path = '/home/tharvey/work/output/BPASS_Chab_LogNorm_5_z_12_phot_grid2.hdf5'
# Out:
# Device: cuda
# Pytorch version: 2.4.1
# ROCM HIP version: 6.1.40093-e3dc58bf0

# %%
fitter = SBI_Fitter.init_from_hdf5('BPASS_Chab_LogNorm_5_z_12_optimize', 
                                grid_path, return_output=False)

fitter.create_feature_array_from_raw_photometry();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fitter = SBI_Fitter.init_from_hdf5('BPASS_Chab_LogNorm_5_z_12_optimize',
#       2                                 grid_path, return_output=False)
#       4 fitter.create_feature_array_from_raw_photometry();
#
# NameError: name 'SBI_Fitter' is not defined

# %%
fitter.optimize_sbi(study_name='BPASS_Chab_LogNorm_5_z_12_optimize',
                    suggested_hyperparameters=
                        {
                            "learning_rate": [1e-6, 1e-3],
                            "hidden_features": [12, 200],
                            "num_components": [2, 16],
                            "training_batch_size": [32, 128],
                            "num_transforms": [1, 4],
                            "stop_after_epochs": [10, 30],
                        },
                    n_trials=10,
                    n_jobs=6,
                    verbose=True,
)
# Out:
# [I 2025-05-09 19:14:31,955] A new study created in memory with name: BPASS_Chab_LogNorm_5_z_12_optimize
# train None
# Splitting dataset with 49999 samples into training and testing sets with 0.80 train fraction.
#   0%|          | 0/10 [00:00<?, ?it/s]
# INFO:root:MODEL INFERENCE CLASS: NPE
# INFO:root:MODEL INFERENCE CLASS: NPE
# INFO:root:MODEL INFERENCE CLASS: NPE
# INFO:root:MODEL INFERENCE CLASS: NPE
# INFO:root:MODEL INFERENCE CLASS: NPE
# INFO:root:MODEL INFERENCE CLASS: NPE
# INFO:root:Training model 1 / 1.
# INFO:root:Training model 1 / 1.
# INFO:root:Training model 1 / 1.
# INFO:root:Training model 1 / 1.
# INFO:root:Training model 1 / 1.
# INFO:root:Training model 1 / 1.
# ---------------------------------------------
# Prior ranges:
# ---------------------------------------------
# log_mass: 5.00 - 11.00
# Pop_II_LogNormal_SFH_5_z_12_logN_4.7_simple/tau_v: 0.00 - 2.00
# Pop_II_LogNormal_SFH_5_z_12_logN_4.7_simple/tau: 0.05 - 2.50
# ...
